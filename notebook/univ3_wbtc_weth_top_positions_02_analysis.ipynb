# %%
import numpy as np
import pandas as pd
import dataframe_image as dfi # for saving styled data frame print-out table as png

pd.set_option('display.max_columns', 15)
pd.set_option('display.max_rows', 50)
pd.options.display.float_format = '{:,.4f}'.format

# %% [markdown]
# ## Analyze Top WBTC-WETH Uniswap V3 Pools
#
# This table of [Top Pools](https://revert.finance/#/top-positions?sort=underlying_value&underlying-value-from=20000&apr-from=20&token1=0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2&token0=0x2260fac5e5542a773aa44fbcfedf7c193bc2c599&age-from=14)
# was scraped from revert finance. Check out the [scraping script](https://github.com/coindataschool/mixture/blob/main/notebook/univ3_wbtc_weth_top_positions_01_scrape_data.ipynb).

# %%
df = pd.read_csv('univ3_wbtc_weth_lp_top_positions.csv').drop(columns=['Unnamed: 0', 'url'])
df['APR'] = df.APR/100
df['fee_APR'] = df.fee_APR/100
df
# Out:
#    pool_fees          PnL    APR  fee_APR          value      age  price_lwr  \
# 0      0.30% 106,365.0500 0.4517   0.3012 1,046,215.0800  60.9000    12.1445
# 1      0.30%  36,387.8100 0.2540   0.2550 1,028,372.0800  54.9000    13.6108
# 2      0.05%  13,307.0900 0.4624   0.5435   483,201.5500  21.6000    14.6416
# 3      0.30%  20,582.7400 0.2822   0.2881   302,677.7000  87.8000    12.0718
# 4      0.05%   4,206.2700 0.2988   0.3786   207,121.8900  24.7000    13.3681
# 5      0.30%   3,060.1800 0.2333   0.2490   183,889.7100  26.0000    13.3681
# 6      0.30%   2,981.9300 0.2797   0.2823   171,629.7100  22.7000    13.7752
# 7      0.30%   1,985.5100 0.2034   0.2729   149,806.2100  23.9000    12.9730
# 8      0.30%   2,150.8600 0.3523   0.3800   149,191.2900  14.9000    14.1947
# 9      0.30%   5,233.2400 0.2018   0.2032   130,548.6600  72.5000    11.1660
# 10     0.05%   7,895.9900 0.2947   0.3010   127,893.2200  77.8000    12.2542
# 11     0.30%  33,247.5500 0.2220   0.2588   126,303.2900 424.9000    14.0253
# 12     0.30%  11,344.9300 0.3924   0.3929   117,532.2000  89.8000    12.4394
# 13     0.30%   2,147.2300 0.3616   0.4939    89,831.6400  23.9000    13.6108
# 14     0.30%   1,186.6900 0.2172   0.2590    78,746.5400  25.3000    12.9730
# 15     0.05%   2,681.9300 0.2641   0.3105    52,696.2900  69.7000    12.3527
# 16     0.30%     568.6400 0.2251   0.2622    51,989.5100  17.8000    13.6928
# 17     0.30%     466.3600 0.2287   0.2498    49,922.1400  14.9000    13.8581
# 18     0.30%   4,799.6600 0.2091   0.2228    47,570.5600 177.1000    12.3650
# 19     0.05%   1,051.2700 0.3305   0.3814    44,017.3500  26.3000    13.3014
# 20     0.30%   2,505.4600 0.2486   0.2538    42,322.0400  86.9000    12.1445
# 21     0.30%     524.0500 0.2022   0.2422    36,908.6000  25.6000    12.5143
# 22     0.05%   4,389.1600 0.2359   0.2382    33,582.8400 202.0000    12.5268
# 23     0.30%     970.6300 0.4340   0.4566    31,160.7600  26.2000    13.6928
# 24     0.30%     589.2100 0.2874   0.3507    29,509.5500  25.2000    13.2086
# 25     0.30%   8,688.9000 0.2181   0.2236    28,677.2500 503.2000    14.1947
# 26     0.30%     446.1400 0.2826   0.2845    25,286.0100  22.8000    14.2801
# 27     0.30%     271.2200 0.2075   0.2104    20,765.5000  23.0000    13.3681
# 28     0.30%     992.8700 0.5139   0.8343    20,456.0300  33.5000    14.3660
#
#     price_upr
# 0     13.6928
# 1     15.9086
# 2     15.3001
# 3     15.9086
# 4     15.3308
# 5     16.6908
# 6     16.1006
# 7     15.6248
# 8     15.0724
# 9     14.4525
# 10    14.2801
# 11    15.5314
# 12    13.2086
# 13    14.9822
# 14    15.9086
# 15    14.9523
# 16    15.5314
# 17    15.3461
# 18    15.3461
# 19    15.3922
# 20    15.6248
# 21    15.6248
# 22    13.6791
# 23    15.4384
# 24    15.3461
# 25    16.6908
# 26    16.6908
# 27    16.6908
# 28    14.8926

# %%
df['pool_fees'].value_counts()
# Out:
# 0.30%    23
# 0.05%     6
# Name: pool_fees, dtype: int64

# %% [markdown]
# ### Age & APR by Pool Type

# %%
ha = df.groupby('pool_fees')[['age', 'fee_APR', 'APR']].aggregate(['min']) 
dfi.export(ha, '../png/min_age_apr_by_pool_type.png')
# Out:
# [1031/092513.261205:INFO:headless_shell.cc(657)] Written to file /var/folders/qq/v47zfw7s1kn38gw67q4v194r0000gn/T/tmpq8w2krr0/temp.png.

# %%
ha = df.groupby('pool_fees')[['age', 'fee_APR', 'APR']].aggregate(['median'])
dfi.export(ha, '../png/med_age_apr_by_pool_type.png')
# Out:
# [1031/092528.166795:INFO:headless_shell.cc(657)] Written to file /var/folders/qq/v47zfw7s1kn38gw67q4v194r0000gn/T/tmp53g4isnh/temp.png.

# %%
ha = df.groupby('pool_fees')[['age', 'fee_APR', 'APR']].aggregate(['max'])
dfi.export(ha, '../png/max_age_apr_by_pool_type.png')
# Out:
# [1031/092537.917769:INFO:headless_shell.cc(657)] Written to file /var/folders/qq/v47zfw7s1kn38gw67q4v194r0000gn/T/tmpfzd3chrc/temp.png.

# %% [markdown]
# ### Price Range by Pool Type

# %%
ha = df.groupby('pool_fees')[['price_lwr', 'price_upr']].aggregate(['min', 'median', 'max'])
dfi.export(ha, '../png/price_rng_by_pool_type.png')
# Out:
# [1031/092619.265162:INFO:headless_shell.cc(657)] Written to file /var/folders/qq/v47zfw7s1kn38gw67q4v194r0000gn/T/tmpc0241u4_/temp.png.

# %%
# clean data
df['PnL'] = df.PnL.str.strip('$').str.replace(',', '').astype(float)
df['APR'] = df.APR.str.strip('%').astype(float)
df['fee APR'] = df['fee APR'].str.strip('%').astype(float)
df['value'] = df.value.str.strip('$').str.replace(',', '').astype(float)
df['age'] = df.age.str.replace(' days', '').astype(float)
df['price_lwr'], df['price_upr'] = zip(*df.price_range.str.split(' - '))

# %%
df = df.rename(columns={'nft_id/owner':'url'})
df.columns = df.columns.str.replace('/| ', '_', regex=True)
df = df.drop(columns='price_range')
df
# Out:
#    pool_fees                                                url          PnL  \
# 0      0.30%  https://revert.finance/#/uniswap-position/main... 106,365.0500
# 1      0.30%  https://revert.finance/#/uniswap-position/main...  36,387.8100
# 2      0.05%  https://revert.finance/#/uniswap-position/main...  13,307.0900
# 3      0.30%  https://revert.finance/#/uniswap-position/main...  20,582.7400
# 4      0.05%  https://revert.finance/#/uniswap-position/main...   4,206.2700
# 5      0.30%  https://revert.finance/#/uniswap-position/main...   3,060.1800
# 6      0.30%  https://revert.finance/#/uniswap-position/main...   2,981.9300
# 7      0.30%  https://revert.finance/#/uniswap-position/main...   1,985.5100
# 8      0.30%  https://revert.finance/#/uniswap-position/main...   2,150.8600
# 9      0.30%  https://revert.finance/#/uniswap-position/main...   5,233.2400
# 10     0.05%  https://revert.finance/#/uniswap-position/main...   7,895.9900
# 11     0.30%  https://revert.finance/#/uniswap-position/main...  33,247.5500
# 12     0.30%  https://revert.finance/#/uniswap-position/main...  11,344.9300
# 13     0.30%  https://revert.finance/#/uniswap-position/main...   2,147.2300
# 14     0.30%  https://revert.finance/#/uniswap-position/main...   1,186.6900
# 15     0.05%  https://revert.finance/#/uniswap-position/main...   2,681.9300
# 16     0.30%  https://revert.finance/#/uniswap-position/main...     568.6400
# 17     0.30%  https://revert.finance/#/uniswap-position/main...     466.3600
# 18     0.30%  https://revert.finance/#/uniswap-position/main...   4,799.6600
# 19     0.05%  https://revert.finance/#/uniswap-position/main...   1,051.2700
# 20     0.30%  https://revert.finance/#/uniswap-position/main...   2,505.4600
# 21     0.30%  https://revert.finance/#/uniswap-position/main...     524.0500
# 22     0.05%  https://revert.finance/#/uniswap-position/main...   4,389.1600
# 23     0.30%  https://revert.finance/#/uniswap-position/main...     970.6300
# 24     0.30%  https://revert.finance/#/uniswap-position/main...     589.2100
# 25     0.30%  https://revert.finance/#/uniswap-position/main...   8,688.9000
# 26     0.30%  https://revert.finance/#/uniswap-position/main...     446.1400
# 27     0.30%  https://revert.finance/#/uniswap-position/main...     271.2200
# 28     0.30%  https://revert.finance/#/uniswap-position/main...     992.8700
#
#        APR  fee_APR          value      age price_lwr price_upr
# 0  45.1700  30.1200 1,046,215.0800  60.9000   12.1445   13.6928
# 1  25.4000  25.5000 1,028,372.0800  54.9000   13.6108   15.9086
# 2  46.2400  54.3500   483,201.5500  21.6000   14.6416   15.3001
# 3  28.2200  28.8100   302,677.7000  87.8000   12.0718   15.9086
# 4  29.8800  37.8600   207,121.8900  24.7000   13.3681   15.3308
# 5  23.3300  24.9000   183,889.7100  26.0000   13.3681   16.6908
# 6  27.9700  28.2300   171,629.7100  22.7000   13.7752   16.1006
# 7  20.3400  27.2900   149,806.2100  23.9000   12.9730   15.6248
# 8  35.2300  38.0000   149,191.2900  14.9000   14.1947   15.0724
# 9  20.1800  20.3200   130,548.6600  72.5000   11.1660   14.4525
# 10 29.4700  30.1000   127,893.2200  77.8000   12.2542   14.2801
# 11 22.2000  25.8800   126,303.2900 424.9000   14.0253   15.5314
# 12 39.2400  39.2900   117,532.2000  89.8000   12.4394   13.2086
# 13 36.1600  49.3900    89,831.6400  23.9000   13.6108   14.9822
# 14 21.7200  25.9000    78,746.5400  25.3000   12.9730   15.9086
# 15 26.4100  31.0500    52,696.2900  69.7000   12.3527   14.9523
# 16 22.5100  26.2200    51,989.5100  17.8000   13.6928   15.5314
# 17 22.8700  24.9800    49,922.1400  14.9000   13.8581   15.3461
# 18 20.9100  22.2800    47,570.5600 177.1000   12.3650   15.3461
# 19 33.0500  38.1400    44,017.3500  26.3000   13.3014   15.3922
# 20 24.8600  25.3800    42,322.0400  86.9000   12.1445   15.6248
# 21 20.2200  24.2200    36,908.6000  25.6000   12.5143   15.6248
# 22 23.5900  23.8200    33,582.8400 202.0000   12.5268   13.6791
# 23 43.4000  45.6600    31,160.7600  26.2000   13.6928   15.4384
# 24 28.7400  35.0700    29,509.5500  25.2000   13.2086   15.3461
# 25 21.8100  22.3600    28,677.2500 503.2000   14.1947   16.6908
# 26 28.2600  28.4500    25,286.0100  22.8000   14.2801   16.6908
# 27 20.7500  21.0400    20,765.5000  23.0000   13.3681   16.6908
# 28 51.3900  83.4300    20,456.0300  33.5000   14.3660   14.8926

# %%
df.to_csv('univ3_wbtc_weth_lp_top_positions.csv')
